# %%
from delta import configure_spark_with_delta_pip, DeltaTable
from pyspark.sql import SparkSession
from pyspark.sql.functions import expr, lit

# %%
builder = (SparkSession.builder
           .appName("upsert-delta-table")
           .master("spark://spark-master:7077")
           .config("spark.executor.memory", "512m")
           .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
           .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog"))

spark = configure_spark_with_delta_pip(builder).getOrCreate()
spark.sparkContext.setLogLevel("ERROR")
# Out:
# :: loading settings :: url = jar:file:/usr/local/lib/python3.10/dist-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# io.delta#delta-core_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-605bb915-14e7-4a61-a3b9-47091d34a11a;1.0
# 	confs: [default]
# 	found io.delta#delta-core_2.12;2.4.0 in central
# 	found io.delta#delta-storage;2.4.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# :: resolution report :: resolve 284ms :: artifacts dl 15ms
# 	:: modules in use:
# 	io.delta#delta-core_2.12;2.4.0 from central in [default]
# 	io.delta#delta-storage;2.4.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   0   |   0   |   0   ||   3   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-605bb915-14e7-4a61-a3b9-47091d34a11a
# 	confs: [default]
# 	0 artifacts copied, 3 already retrieved (0kB/11ms)
# 24/02/04 17:04:49 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
# %load_ext sparksql_magic
# %config SparkSql.limit=20

# %%
import os
print(os.listdir(os.path.abspath(os.path.join(os.getcwd(), ".."))))
# Out:
# ['__init__.py', '__pycache__', 'hello_delta.ipynb', 'Chapter08', 'Chapter06', 'Chapter09', 'Chapter03', 'Chapter04', 'Chapter02', '.ipynb_checkpoints', 'hello_spark.ipynb', 'Chapter10', 'Chapter07', 'Chapter05', 'Chapter11', 'initialize_spark.py', 'data']

# %%
import sys
import os

# Add the parent directory one level up to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# Import the initialize_spark function from the package
from notebooks.config.initialize_spark import initialize_spark

# Initialize the Spark session and delta table path
spark, delta_table_path = initialize_spark()
# Out:
# The sparksql_magic extension is already loaded. To reload it, use:
#   %reload_ext sparksql_magic
# initialize_spark.py is being imported
# 24/08/23 13:17:46 ERROR TaskSchedulerImpl: Lost executor 1 on 172.19.0.5: Remote RPC client disassociated. Likely due to containers exceeding thresholds, or network issues. Check driver logs for WARN messages.
# 24/08/23 13:17:46 ERROR TaskSchedulerImpl: Lost executor 0 on 172.19.0.6: Remote RPC client disassociated. Likely due to containers exceeding thresholds, or network issues. Check driver logs for WARN messages.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 spark, delta_table_path = initialize_spark.initialize_spark()
#
# NameError: name 'initialize_spark' is not defined

# %%
# For PySpark:
deltaTable = DeltaTable.forPath(spark, delta_table_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # For PySpark:
# ----> 2 deltaTable = DeltaTable.forPath(spark, delta_table_path)
#
# NameError: name 'spark' is not defined

# %%
deltaTable.toDF().show(5)

# %%
# Update director to not have nulls
deltaTable.update(
  condition = expr("director IS NULL"),
  set = { "director": lit("") })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Update director to not have nulls
# ----> 2 deltaTable.update(
#       3   condition = expr("director IS NULL"),
#       4   set = { "director": lit("") })
#
# NameError: name 'deltaTable' is not defined

# %%
# %%sparksql
# UPDATE delta.`/opt/workspace/data/delta_lake/netflix_titles` SET director = "" WHERE director IS NULL;

# %%
# Show a sample of the data
deltaTable.toDF().show(5)

# %%
spark.stop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 spark.stop()
#
# NameError: name 'spark' is not defined
