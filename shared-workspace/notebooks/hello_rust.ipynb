// %%
// Print a welcome message
println!("Hello, World! Welcome to Rust in Jupyter Notebook.");

// Define and print a variable
let number = 5;
println!("The value of the variable 'number' is: {}", number);

// Simulate user input
let name = "JupyterUser";
println!("Hello, {}!", name);

// Simple loop example with output
println!("Counting from 1 to 5:");
for i in 1..=5 {
    println!("{}", i);
}
// Out:
// Hello, World! Welcome to Rust in Jupyter Notebook.
// The value of the variable 'number' is: 5
// Hello, JupyterUser!
// Counting from 1 to 5:
// 1
// 2
// 3
// 4
// 5
// ()
